# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = gpd.read_file("../data/Methylene/S2A_MSIL1C_20180607T085601_N0206_R007_T35SMD_20180607T110513/outliers.shp")
df.head()
# Out:
#    NORM_FDI  NORM_NDVI       B06        B07        B11  \
# 0 -0.052212   7.943726  2.954620  -2.239502   4.454880
# 1  0.009545 -11.826477  9.368469  39.671783  30.627579
# 2  0.060959  48.429596  9.499542   3.743988   7.031113
# 3  0.024733  31.996597  1.637726  12.939087  14.630539
# 4 -0.018815  16.513779  4.646729  17.398163   9.299042
#
#                                             geometry
# 0  POLYGON ((26.01601 38.88837, 26.01590 38.88837...
# 1  POLYGON ((26.03792 38.88828, 26.03780 38.88828...
# 2  POLYGON ((26.06963 38.88809, 26.06951 38.88809...
# 3  POLYGON ((26.03114 38.88642, 26.03103 38.88642...
# 4  POLYGON ((26.03425 38.88645, 26.03414 38.88645...

# %%
df.shape
# Out:
# (756601, 6)

# %%
feature = df.iloc[:,:-1].values
feature.shape
# Out:
# (756601, 5)

# %%
fig = plt.figure(figsize=(20,15))
plt.scatter(feature[:,0], feature[:,1], s=1)
plt.show()
